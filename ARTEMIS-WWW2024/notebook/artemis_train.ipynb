# %%
# !pip install torch_geometric
# !pip install torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.2.0)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.4.0
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+cu121.html
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_scatter-2.1.2%2Bpt21cu121-cp310-cp310-linux_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 83.3 MB/s eta 0:00:00
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_sparse-0.6.18%2Bpt21cu121-cp310-cp310-linux_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 49.8 MB/s eta 0:00:00
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_cluster-1.6.3%2Bpt21cu121-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 50.0 MB/s eta 0:00:00
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_spline_conv-1.2.2%2Bpt21cu121-cp310-cp310-linux_x86_64.whl (932 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.1/932.1 kB 50.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_sparse) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->torch_sparse) (1.25.2)
# Installing collected packages: torch_spline_conv, torch_scatter, torch_sparse, torch_cluster
# Successfully installed torch_cluster-1.6.3+pt21cu121 torch_scatter-2.1.2+pt21cu121 torch_sparse-0.6.18+pt21cu121 torch_spline_conv-1.2.2+pt21cu121

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import torch
from torch import Tensor
from torch_geometric.loader.neighbor_sampler import NeighborSampler, Adj, EdgeIndex

class NeighborSamplerbyNFT(NeighborSampler):
    def __init__(self, edge_index, sizes, edge_attr=None, transform=None, prob_vector=None, **kwargs):
        super(NeighborSamplerbyNFT, self).__init__(edge_index, sizes=sizes, transform=transform, **kwargs)
        self.edge_attr = edge_attr.to('cpu') if edge_attr is not None else None
        self.first_layer_edge_attr = None  # Store the edge attributes of the first layer
        self.prob_vector = prob_vector


    def sample(self, batch):
        if not isinstance(batch, Tensor):
            batch = torch.tensor(batch, dtype=torch.long)

        batch_size: int = len(batch)
        adjs = []
        n_id = batch
        if self.prob_vector is not None:
            n_id = torch.multinomial(self.prob_vector, num_samples=len(n_id), replacement=True)

        for i, size in enumerate(self.sizes):
            adj_t, n_id = self.adj_t.sample_adj(n_id, size, replace=False)
            e_id = adj_t.storage.value()
            size = adj_t.sparse_sizes()[::-1]

            if self.edge_attr is not None:
                edge_attr = self.edge_attr[e_id].to('cpu')  # Ensure edge_attr is on CPU
                if i == 0:
                    # Store the edge attributes for the first layer
                    self.first_layer_edge_attr = edge_attr
                else:
                    # Compute the mask based on the stored first layer edge attributes
                    mask = self.compute_mask(edge_attr, self.first_layer_edge_attr)
                    adj_t = adj_t.masked_select_nnz(mask, layout='coo')
                    e_id = adj_t.storage.value()
                    size = adj_t.sparse_sizes()[::-1]

            if self.is_sparse_tensor:
                adjs.append(Adj(adj_t, e_id, size))
            else:
                row, col, _ = adj_t.coo()
                edge_index = torch.stack([col, row], dim=0)
                adjs.append(EdgeIndex(edge_index, e_id, size))

        adjs = adjs[0] if len(adjs) == 1 else adjs[::-1]
        out = (batch_size, n_id, adjs)
        out = self.transform(*out) if self.transform is not None else out
        return out

    def compute_mask(self, edge_attr, first_layer_edge_attr):
        # Compute the mask by checking if the edge attributes match any of the first layer edge attributes
        mask = (edge_attr[:, None] == first_layer_edge_attr).all(dim=-1).any(dim=1)
        return mask

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, BatchNorm
from torch_geometric.nn import MessagePassing

class ArtemisFirstLayerConv(MessagePassing):
    def __init__(self, in_node_channels, in_edge_channels, out_channels, aggr='mean'):
        super(ArtemisFirstLayerConv, self).__init__(aggr=aggr)
        self.lin = nn.Linear(in_node_channels + in_edge_channels, out_channels)
        self.aggr = aggr

    def forward(self, x, edge_index, edge_attr):
        return self.propagate(edge_index, size=(x.size(0), x.size(0)), x=x, edge_attr=edge_attr)

    def message(self, x_j, edge_attr):
        return self.lin(torch.cat([x_j, edge_attr], dim=-1))

    def update(self, aggr_out):
        return F.relu(aggr_out)

class ArtemisNet(nn.Module):
    def __init__(self, in_node_channels, in_edge_channels, hidden_channels):
        super(ArtemisNet, self).__init__()
        self.conv1 = ArtemisFirstLayerConv(in_node_channels, in_edge_channels, hidden_channels)
        self.bn1 = BatchNorm(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = BatchNorm(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.bn3 = BatchNorm(hidden_channels)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_channels + in_node_channels, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1)
        )

    def forward(self, x, edge_index_tuple, edge_attr_tuple):
        edge_index_0, edge_index_1, edge_index_2 = edge_index_tuple
        edge_attr_0, _, _ = edge_attr_tuple

        # First layer with residual connection
        inital_embedding = x
        x = self.conv1(x, edge_index_0, edge_attr_0)
        x = F.relu(self.bn1(x))
        x = F.dropout(x, p=0.5, training=self.training)

        # Second layer with residual connection
        x = self.conv2(x, edge_index_1)
        x = F.relu(self.bn2(x))
        x = F.dropout(x, p=0.5, training=self.training)

        # Third layer with residual connection
        x = self.conv3(x, edge_index_2)
        x = F.relu(self.bn3(x))
        x = F.dropout(x, p=0.5, training=self.training)

        # Apply MLP to the final output
        x = torch.cat([x, inital_embedding], dim=1)
        x = self.mlp(x)
        return x.squeeze()

# %%
import torch
import torch.nn as nn
import torch_geometric
from torch_geometric.data import Data
import numpy as np
import random
import sys
from torch_geometric.data import DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

node_basic_features = torch.load('./WWW 2024/node_basic_features.pt').to(device)
node_advanced_features = torch.load('./WWW 2024/node_advanced_features.pt').to(device)
edge_index = torch.load('./WWW 2024/edge_index.pt').to(device)
base_edge_features = torch.load('./WWW 2024/base_edge_features.pt').to(device)
nft_multimodal_bmbedding_features = torch.load('./WWW 2024/nft_multimodal_bmbedding_features.pt').to(device)
y = torch.load('./WWW 2024/y.pt').to(device)
node_sample_prob = torch.load('./WWW 2024/node_sample_prob.pt')
node_sample_prob = node_sample_prob / node_sample_prob.sum()

node_features = torch.cat([node_basic_features, node_advanced_features], dim=1)
edge_features = torch.cat([base_edge_features, nft_multimodal_bmbedding_features], dim=1)

# %%
train_mask = np.zeros(y.shape[0], dtype=np.bool_)
test_mask = np.zeros(y.shape[0], dtype=np.bool_)
train_test_split_num = int(y.shape[0] * 0.9)
train_index = random.sample(range(y.shape[0]), train_test_split_num)
test_index = list(set(range(y.shape[0])) - set(train_index))
train_mask[train_index] = True
test_mask[test_index] = True
print("train node num: ", train_mask.sum())
print("test node num: ", test_mask.sum())
print("true data percentage in train data: ", y[train_mask].sum() / len(y[train_mask]))
print("true data percentage in test data: ", y[test_mask].sum() / len(y[test_mask]))

data = Data(x=node_basic_features, y=y,
            edge_index=edge_index, edge_attr=edge_features,
            train_mask=train_mask, test_mask=test_mask).to(device)
# Out:
# train node num:  182790
# test node num:  20311
# true data percentage in train data:  tensor(0.0237, device='cuda:0')
# true data percentage in test data:  tensor(0.0234, device='cuda:0')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from torch.utils.data import DataLoader, WeightedRandomSampler

import os

log_path = "./WWW 2024/artemis_model_log.txt"

if os.path.exists(log_path):
    os.remove(log_path)

with open(log_path, "a") as log_file:
    log_file.write("Epoch, Average Loss, Average Accuracy, Average Precision, Average Recall, Average F1 Score\n")


for run in range(5):
    print(f"Starting run {run+1}...\n")
    with open(log_path, "a") as log_file:

        model = ArtemisNet(data.x.shape[1], data.edge_attr.shape[1], 32).to(device)

        num_pos = data.y[data.train_mask].sum().item()
        num_neg = data.train_mask.sum().item() - num_pos
        class_weights = torch.tensor([1], dtype=torch.float32).to(device)
        criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=5e-4)


        sizes = [8, 1, 1]
        edge_sampler = NeighborSamplerbyNFT(edge_index=data.edge_index, sizes=sizes, edge_attr=data.edge_attr, prob_vector=node_sample_prob)
        patience = 10
        best_loss = float('inf')
        patience_counter = 0

        train_nodes = torch.where(torch.from_numpy(data.train_mask))[0]  # Keep train_nodes on CPU


        labels = data.y[data.train_mask].cpu().numpy()

        class_counts = np.bincount(labels)
        weights = 1. / torch.tensor(class_counts, dtype=torch.float32)
        sample_weights = weights[labels]

        # WeightedRandomSampler
        sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=False)

        patience = 10
        best_loss = float('inf')
        patience_counter = 0

        best_model = None
        best_f1 = 0.0

        for epoch in range(100):
            model.train()
            total_loss = 0
            total_accuracy = 0
            total_precision = 0
            total_recall = 0
            total_f1 = 0
            batch_count = 0

            for subset_nodes in DataLoader(train_nodes, batch_size=256, sampler=sampler):
                batch_size, n_id, adjs = edge_sampler.sample(subset_nodes)
                n_id = n_id.to(device)

                optimizer.zero_grad()

                edge_index_0, e_id_0, size_0 = adjs[0].edge_index, adjs[0].e_id, adjs[0].size
                edge_attr_0 = data.edge_attr[e_id_0].to(device)
                edge_index_1, _, size_1 = adjs[1].edge_index, adjs[1].e_id, adjs[1].size
                edge_index_2, _, size_2 = adjs[2].edge_index, adjs[2].e_id, adjs[2].size

                out = model(data.x[n_id], (edge_index_0.to(device), edge_index_1.to(device), edge_index_2.to(device)), (edge_attr_0, None, None))

                loss = criterion(out, data.y[n_id].float())
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

                predictions = torch.sigmoid(out)
                pred_binary = (predictions >= 0.5).int()
                pred = pred_binary.cpu()
                y = data.y[n_id].int().cpu()

                total_accuracy += accuracy_score(y.numpy(), pred.numpy())
                total_precision += precision_score(y.numpy(), pred.numpy(), zero_division=1)
                total_recall += recall_score(y.numpy(), pred.numpy())
                total_f1 += f1_score(y.numpy(), pred.numpy())

                batch_count += 1

            avg_loss = total_loss / batch_count
            avg_accuracy = total_accuracy / batch_count
            avg_precision = total_precision / batch_count
            avg_recall = total_recall / batch_count
            avg_f1 = total_f1 / batch_count

            print(f"Epoch {epoch} | Average Loss: {avg_loss:.5f} | Average Accuracy: {avg_accuracy:.3f} | "
                f"Average Precision: {avg_precision:.3f} | Average Recall: {avg_recall:.3f} | "
                f"Average F1 Score: {avg_f1:.3f}")
            log_file.write(f"{epoch}, {avg_loss:.5f}, {avg_accuracy:.3f}, {avg_precision:.3f}, {avg_recall:.3f}, {avg_f1:.3f}\n")

            if avg_loss < best_loss:
                best_loss = avg_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter == patience:
                    print("Stopping early due to lack of improvement on the validation set.")
                    break

            model.eval()
            test_nodes = torch.where(torch.from_numpy(data.test_mask))[0]
            with torch.no_grad():
                batch_size, n_id, adjs = edge_sampler.sample(test_nodes)
                n_id = n_id.to(device)

                edge_index_0, e_id_0, size_0 = adjs[0].edge_index, adjs[0].e_id, adjs[0].size
                edge_attr_0 = data.edge_attr[e_id_0].to(device)
                edge_index_1, _, size_1 = adjs[1].edge_index, adjs[1].e_id, adjs[1].size
                edge_index_2, _, size_2 = adjs[2].edge_index, adjs[2].e_id, adjs[2].size

                out = model(data.x[n_id], (edge_index_0.to(device), edge_index_1.to(device), edge_index_2.to(device)), (edge_attr_0, None, None))

                predictions = torch.sigmoid(out)
                pred_binary = (predictions >= 0.5).int()
                pred = pred_binary.cpu()
                y = data.y[n_id].int().cpu()
                accuracy = accuracy_score(y.numpy(), pred.numpy())
                precision = precision_score(y.numpy(), pred.numpy(), zero_division=1)
                recall = recall_score(y.numpy(), pred.numpy())
                f1 = f1_score(y.numpy(), pred.numpy())

                if f1 > best_f1:
                    best_f1 = f1
                    best_model = model.state_dict().copy()


        model.load_state_dict(best_model)
        model.eval()
        test_nodes = torch.where(torch.from_numpy(data.test_mask))[0]
        with torch.no_grad():
            batch_size, n_id, adjs = edge_sampler.sample(test_nodes)
            n_id = n_id.to(device)

            edge_index_0, e_id_0, size_0 = adjs[0].edge_index, adjs[0].e_id, adjs[0].size
            edge_attr_0 = data.edge_attr[e_id_0].to(device)
            edge_index_1, _, size_1 = adjs[1].edge_index, adjs[1].e_id, adjs[1].size
            edge_index_2, _, size_2 = adjs[2].edge_index, adjs[2].e_id, adjs[2].size

            out = model(data.x[n_id], (edge_index_0.to(device), edge_index_1.to(device), edge_index_2.to(device)), (edge_attr_0, None, None))

            predictions = torch.sigmoid(out)
            pred_binary = (predictions >= 0.5).int()
            pred = pred_binary.cpu()
            y = data.y[n_id].int().cpu()
            accuracy = accuracy_score(y.numpy(), pred.numpy())
            precision = precision_score(y.numpy(), pred.numpy(), zero_division=1)
            recall = recall_score(y.numpy(), pred.numpy())
            f1 = f1_score(y.numpy(), pred.numpy())

            print(f"Test - Accuracy: {accuracy:.3f}, Precision: {precision:.3f}, Recall: {recall:.3f}, F1 Score: {f1:.3f}")
            log_file.write(f"Test - Run {run+1}, Accuracy: {accuracy:.3f}, Precision: {precision:.3f}, Recall: {recall:.3f}, F1 Score: {f1:.3f}\n\n")

        print(f"Run {run+1} completed.\n")
# Out:
# Starting run 1...
#
# Epoch 0 | Average Loss: 5.59800 | Average Accuracy: 0.606 | Average Precision: 0.471 | Average Recall: 0.842 | Average F1 Score: 0.598
# Epoch 1 | Average Loss: 1.11412 | Average Accuracy: 0.813 | Average Precision: 0.669 | Average Recall: 0.871 | Average F1 Score: 0.756
# Epoch 2 | Average Loss: 0.51414 | Average Accuracy: 0.853 | Average Precision: 0.726 | Average Recall: 0.895 | Average F1 Score: 0.802
# Epoch 3 | Average Loss: 0.37783 | Average Accuracy: 0.873 | Average Precision: 0.756 | Average Recall: 0.912 | Average F1 Score: 0.826
# Epoch 4 | Average Loss: 0.31241 | Average Accuracy: 0.890 | Average Precision: 0.791 | Average Recall: 0.912 | Average F1 Score: 0.847
# Epoch 5 | Average Loss: 0.28223 | Average Accuracy: 0.900 | Average Precision: 0.811 | Average Recall: 0.912 | Average F1 Score: 0.858
# Epoch 6 | Average Loss: 0.26440 | Average Accuracy: 0.906 | Average Precision: 0.825 | Average Recall: 0.910 | Average F1 Score: 0.866
# Epoch 7 | Average Loss: 0.25026 | Average Accuracy: 0.912 | Average Precision: 0.839 | Average Recall: 0.909 | Average F1 Score: 0.872
# Epoch 8 | Average Loss: 0.23939 | Average Accuracy: 0.917 | Average Precision: 0.852 | Average Recall: 0.908 | Average F1 Score: 0.879
# Epoch 9 | Average Loss: 0.23130 | Average Accuracy: 0.920 | Average Precision: 0.860 | Average Recall: 0.906 | Average F1 Score: 0.882
# Epoch 10 | Average Loss: 0.22445 | Average Accuracy: 0.922 | Average Precision: 0.867 | Average Recall: 0.904 | Average F1 Score: 0.885
# Epoch 11 | Average Loss: 0.21965 | Average Accuracy: 0.925 | Average Precision: 0.875 | Average Recall: 0.902 | Average F1 Score: 0.888
# Epoch 12 | Average Loss: 0.21616 | Average Accuracy: 0.926 | Average Precision: 0.880 | Average Recall: 0.902 | Average F1 Score: 0.891
# Epoch 13 | Average Loss: 0.21322 | Average Accuracy: 0.927 | Average Precision: 0.884 | Average Recall: 0.900 | Average F1 Score: 0.892
# Epoch 14 | Average Loss: 0.21072 | Average Accuracy: 0.928 | Average Precision: 0.887 | Average Recall: 0.898 | Average F1 Score: 0.892
# Epoch 15 | Average Loss: 0.20734 | Average Accuracy: 0.929 | Average Precision: 0.892 | Average Recall: 0.897 | Average F1 Score: 0.894
# Epoch 16 | Average Loss: 0.20663 | Average Accuracy: 0.929 | Average Precision: 0.894 | Average Recall: 0.895 | Average F1 Score: 0.894
# Epoch 17 | Average Loss: 0.20354 | Average Accuracy: 0.931 | Average Precision: 0.898 | Average Recall: 0.894 | Average F1 Score: 0.896
# Epoch 18 | Average Loss: 0.20172 | Average Accuracy: 0.931 | Average Precision: 0.900 | Average Recall: 0.893 | Average F1 Score: 0.896
# Epoch 19 | Average Loss: 0.20012 | Average Accuracy: 0.932 | Average Precision: 0.902 | Average Recall: 0.892 | Average F1 Score: 0.897
# Epoch 20 | Average Loss: 0.19902 | Average Accuracy: 0.932 | Average Precision: 0.904 | Average Recall: 0.890 | Average F1 Score: 0.897
# Epoch 21 | Average Loss: 0.19710 | Average Accuracy: 0.932 | Average Precision: 0.906 | Average Recall: 0.889 | Average F1 Score: 0.897
# Epoch 22 | Average Loss: 0.19549 | Average Accuracy: 0.933 | Average Precision: 0.908 | Average Recall: 0.888 | Average F1 Score: 0.898
# Epoch 23 | Average Loss: 0.19454 | Average Accuracy: 0.933 | Average Precision: 0.910 | Average Recall: 0.888 | Average F1 Score: 0.898
# Epoch 24 | Average Loss: 0.19450 | Average Accuracy: 0.933 | Average Precision: 0.909 | Average Recall: 0.886 | Average F1 Score: 0.897
# Epoch 25 | Average Loss: 0.19409 | Average Accuracy: 0.933 | Average Precision: 0.911 | Average Recall: 0.883 | Average F1 Score: 0.897
# Epoch 26 | Average Loss: 0.19413 | Average Accuracy: 0.933 | Average Precision: 0.911 | Average Recall: 0.883 | Average F1 Score: 0.897
# Epoch 27 | Average Loss: 0.19302 | Average Accuracy: 0.932 | Average Precision: 0.912 | Average Recall: 0.882 | Average F1 Score: 0.896
# Epoch 28 | Average Loss: 0.19001 | Average Accuracy: 0.933 | Average Precision: 0.913 | Average Recall: 0.884 | Average F1 Score: 0.898
# Epoch 29 | Average Loss: 0.19026 | Average Accuracy: 0.934 | Average Precision: 0.914 | Average Recall: 0.884 | Average F1 Score: 0.899
# Epoch 30 | Average Loss: 0.18987 | Average Accuracy: 0.933 | Average Precision: 0.914 | Average Recall: 0.884 | Average F1 Score: 0.898
# Epoch 31 | Average Loss: 0.18985 | Average Accuracy: 0.934 | Average Precision: 0.916 | Average Recall: 0.883 | Average F1 Score: 0.899
# Epoch 32 | Average Loss: 0.18882 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.883 | Average F1 Score: 0.899
# Epoch 33 | Average Loss: 0.18864 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 34 | Average Loss: 0.18806 | Average Accuracy: 0.934 | Average Precision: 0.916 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 35 | Average Loss: 0.18665 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 36 | Average Loss: 0.18680 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 37 | Average Loss: 0.18787 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.881 | Average F1 Score: 0.899
# Epoch 38 | Average Loss: 0.18716 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.880 | Average F1 Score: 0.898
# Epoch 39 | Average Loss: 0.18556 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 40 | Average Loss: 0.18574 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 41 | Average Loss: 0.18517 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 42 | Average Loss: 0.18427 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 43 | Average Loss: 0.18466 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 44 | Average Loss: 0.18433 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 45 | Average Loss: 0.18341 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.881 | Average F1 Score: 0.899
# Epoch 46 | Average Loss: 0.18487 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 47 | Average Loss: 0.18393 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 48 | Average Loss: 0.18250 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.885 | Average F1 Score: 0.902
# Epoch 49 | Average Loss: 0.18425 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 50 | Average Loss: 0.18423 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 51 | Average Loss: 0.18414 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 52 | Average Loss: 0.18217 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 53 | Average Loss: 0.18335 | Average Accuracy: 0.935 | Average Precision: 0.916 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 54 | Average Loss: 0.18400 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 55 | Average Loss: 0.18394 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 56 | Average Loss: 0.18323 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 57 | Average Loss: 0.18366 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 58 | Average Loss: 0.18239 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.884 | Average F1 Score: 0.900
# Epoch 59 | Average Loss: 0.18333 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 60 | Average Loss: 0.18216 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.885 | Average F1 Score: 0.901
# Epoch 61 | Average Loss: 0.18387 | Average Accuracy: 0.935 | Average Precision: 0.917 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 62 | Average Loss: 0.18364 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 63 | Average Loss: 0.18372 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 64 | Average Loss: 0.18124 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.884 | Average F1 Score: 0.900
# Epoch 65 | Average Loss: 0.18095 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 66 | Average Loss: 0.18169 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.885 | Average F1 Score: 0.901
# Epoch 67 | Average Loss: 0.18193 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.885 | Average F1 Score: 0.901
# Epoch 68 | Average Loss: 0.18275 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.885 | Average F1 Score: 0.901
# Epoch 69 | Average Loss: 0.18322 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.886 | Average F1 Score: 0.901
# Epoch 70 | Average Loss: 0.18180 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.886 | Average F1 Score: 0.901
# Epoch 71 | Average Loss: 0.18361 | Average Accuracy: 0.935 | Average Precision: 0.918 | Average Recall: 0.884 | Average F1 Score: 0.900
# Epoch 72 | Average Loss: 0.18184 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.887 | Average F1 Score: 0.902
# Epoch 73 | Average Loss: 0.18131 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.887 | Average F1 Score: 0.902
# Epoch 74 | Average Loss: 0.18265 | Average Accuracy: 0.935 | Average Precision: 0.917 | Average Recall: 0.887 | Average F1 Score: 0.901
# Epoch 75 | Average Loss: 0.18129 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.886 | Average F1 Score: 0.902
# Stopping early due to lack of improvement on the validation set.
# Test - Accuracy: 0.966, Precision: 0.806, Recall: 0.862, F1 Score: 0.833
# Run 1 completed.
#
# Starting run 2...
#
# Epoch 0 | Average Loss: 3.59249 | Average Accuracy: 0.684 | Average Precision: 0.528 | Average Recall: 0.856 | Average F1 Score: 0.649
# Epoch 1 | Average Loss: 0.72270 | Average Accuracy: 0.838 | Average Precision: 0.708 | Average Recall: 0.879 | Average F1 Score: 0.784
# Epoch 2 | Average Loss: 0.42070 | Average Accuracy: 0.875 | Average Precision: 0.763 | Average Recall: 0.905 | Average F1 Score: 0.827
# Epoch 3 | Average Loss: 0.32447 | Average Accuracy: 0.895 | Average Precision: 0.798 | Average Recall: 0.913 | Average F1 Score: 0.851
# Epoch 4 | Average Loss: 0.28596 | Average Accuracy: 0.904 | Average Precision: 0.818 | Average Recall: 0.914 | Average F1 Score: 0.863
# Epoch 5 | Average Loss: 0.26749 | Average Accuracy: 0.911 | Average Precision: 0.834 | Average Recall: 0.914 | Average F1 Score: 0.872
# Epoch 6 | Average Loss: 0.25340 | Average Accuracy: 0.915 | Average Precision: 0.846 | Average Recall: 0.911 | Average F1 Score: 0.876
# Epoch 7 | Average Loss: 0.24322 | Average Accuracy: 0.919 | Average Precision: 0.857 | Average Recall: 0.909 | Average F1 Score: 0.882
# Epoch 8 | Average Loss: 0.23049 | Average Accuracy: 0.924 | Average Precision: 0.868 | Average Recall: 0.907 | Average F1 Score: 0.887
# Epoch 9 | Average Loss: 0.22302 | Average Accuracy: 0.926 | Average Precision: 0.876 | Average Recall: 0.905 | Average F1 Score: 0.890
# Epoch 10 | Average Loss: 0.21834 | Average Accuracy: 0.928 | Average Precision: 0.883 | Average Recall: 0.903 | Average F1 Score: 0.893
# Epoch 11 | Average Loss: 0.21536 | Average Accuracy: 0.929 | Average Precision: 0.887 | Average Recall: 0.900 | Average F1 Score: 0.893
# Epoch 12 | Average Loss: 0.21118 | Average Accuracy: 0.930 | Average Precision: 0.891 | Average Recall: 0.898 | Average F1 Score: 0.895
# Epoch 13 | Average Loss: 0.20769 | Average Accuracy: 0.931 | Average Precision: 0.895 | Average Recall: 0.898 | Average F1 Score: 0.897
# Epoch 14 | Average Loss: 0.20637 | Average Accuracy: 0.932 | Average Precision: 0.899 | Average Recall: 0.895 | Average F1 Score: 0.897
# Epoch 15 | Average Loss: 0.20459 | Average Accuracy: 0.932 | Average Precision: 0.900 | Average Recall: 0.894 | Average F1 Score: 0.897
# Epoch 16 | Average Loss: 0.20071 | Average Accuracy: 0.933 | Average Precision: 0.903 | Average Recall: 0.894 | Average F1 Score: 0.898
# Epoch 17 | Average Loss: 0.20064 | Average Accuracy: 0.933 | Average Precision: 0.904 | Average Recall: 0.892 | Average F1 Score: 0.898
# Epoch 18 | Average Loss: 0.19910 | Average Accuracy: 0.933 | Average Precision: 0.906 | Average Recall: 0.891 | Average F1 Score: 0.898
# Epoch 19 | Average Loss: 0.19805 | Average Accuracy: 0.933 | Average Precision: 0.908 | Average Recall: 0.888 | Average F1 Score: 0.898
# Epoch 20 | Average Loss: 0.19791 | Average Accuracy: 0.933 | Average Precision: 0.910 | Average Recall: 0.887 | Average F1 Score: 0.898
# Epoch 21 | Average Loss: 0.19559 | Average Accuracy: 0.934 | Average Precision: 0.911 | Average Recall: 0.887 | Average F1 Score: 0.899
# Epoch 22 | Average Loss: 0.19431 | Average Accuracy: 0.934 | Average Precision: 0.912 | Average Recall: 0.886 | Average F1 Score: 0.899
# Epoch 23 | Average Loss: 0.19419 | Average Accuracy: 0.933 | Average Precision: 0.913 | Average Recall: 0.884 | Average F1 Score: 0.898
# Epoch 24 | Average Loss: 0.19423 | Average Accuracy: 0.934 | Average Precision: 0.915 | Average Recall: 0.884 | Average F1 Score: 0.899
# Epoch 25 | Average Loss: 0.19361 | Average Accuracy: 0.933 | Average Precision: 0.915 | Average Recall: 0.883 | Average F1 Score: 0.898
# Epoch 26 | Average Loss: 0.19168 | Average Accuracy: 0.934 | Average Precision: 0.916 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 27 | Average Loss: 0.19040 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.882 | Average F1 Score: 0.899
# Epoch 28 | Average Loss: 0.19176 | Average Accuracy: 0.934 | Average Precision: 0.916 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 29 | Average Loss: 0.19229 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.879 | Average F1 Score: 0.898
# Epoch 30 | Average Loss: 0.18941 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.879 | Average F1 Score: 0.898
# Epoch 31 | Average Loss: 0.18965 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.880 | Average F1 Score: 0.898
# Epoch 32 | Average Loss: 0.19038 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.879 | Average F1 Score: 0.898
# Epoch 33 | Average Loss: 0.19027 | Average Accuracy: 0.933 | Average Precision: 0.919 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 34 | Average Loss: 0.18872 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 35 | Average Loss: 0.18862 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 36 | Average Loss: 0.18852 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 37 | Average Loss: 0.18667 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.876 | Average F1 Score: 0.897
# Epoch 38 | Average Loss: 0.18653 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 39 | Average Loss: 0.18783 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.877 | Average F1 Score: 0.898
# Epoch 40 | Average Loss: 0.18767 | Average Accuracy: 0.934 | Average Precision: 0.921 | Average Recall: 0.877 | Average F1 Score: 0.898
# Epoch 41 | Average Loss: 0.18754 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.877 | Average F1 Score: 0.898
# Epoch 42 | Average Loss: 0.18586 | Average Accuracy: 0.934 | Average Precision: 0.921 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 43 | Average Loss: 0.18485 | Average Accuracy: 0.935 | Average Precision: 0.921 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 44 | Average Loss: 0.18626 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.876 | Average F1 Score: 0.897
# Epoch 45 | Average Loss: 0.18586 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.877 | Average F1 Score: 0.898
# Epoch 46 | Average Loss: 0.18599 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 47 | Average Loss: 0.18613 | Average Accuracy: 0.934 | Average Precision: 0.921 | Average Recall: 0.877 | Average F1 Score: 0.898
# Epoch 48 | Average Loss: 0.18494 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 49 | Average Loss: 0.18622 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 50 | Average Loss: 0.18560 | Average Accuracy: 0.934 | Average Precision: 0.921 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 51 | Average Loss: 0.18532 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 52 | Average Loss: 0.18512 | Average Accuracy: 0.934 | Average Precision: 0.921 | Average Recall: 0.879 | Average F1 Score: 0.899
# Epoch 53 | Average Loss: 0.18491 | Average Accuracy: 0.935 | Average Precision: 0.921 | Average Recall: 0.879 | Average F1 Score: 0.899
# Stopping early due to lack of improvement on the validation set.
# Test - Accuracy: 0.965, Precision: 0.821, Recall: 0.824, F1 Score: 0.823
# Run 2 completed.
#
# Starting run 3...
#
# Epoch 0 | Average Loss: 7.35488 | Average Accuracy: 0.620 | Average Precision: 0.465 | Average Recall: 0.796 | Average F1 Score: 0.584
# Epoch 1 | Average Loss: 2.03503 | Average Accuracy: 0.806 | Average Precision: 0.663 | Average Recall: 0.857 | Average F1 Score: 0.746
# Epoch 2 | Average Loss: 0.83589 | Average Accuracy: 0.862 | Average Precision: 0.756 | Average Recall: 0.865 | Average F1 Score: 0.807
# Epoch 3 | Average Loss: 0.49793 | Average Accuracy: 0.886 | Average Precision: 0.800 | Average Recall: 0.875 | Average F1 Score: 0.836
# Epoch 4 | Average Loss: 0.37830 | Average Accuracy: 0.899 | Average Precision: 0.824 | Average Recall: 0.886 | Average F1 Score: 0.854
# Epoch 5 | Average Loss: 0.31611 | Average Accuracy: 0.906 | Average Precision: 0.837 | Average Recall: 0.892 | Average F1 Score: 0.863
# Epoch 6 | Average Loss: 0.27901 | Average Accuracy: 0.913 | Average Precision: 0.851 | Average Recall: 0.897 | Average F1 Score: 0.873
# Epoch 7 | Average Loss: 0.26259 | Average Accuracy: 0.917 | Average Precision: 0.860 | Average Recall: 0.897 | Average F1 Score: 0.878
# Epoch 8 | Average Loss: 0.24503 | Average Accuracy: 0.921 | Average Precision: 0.868 | Average Recall: 0.898 | Average F1 Score: 0.883
# Epoch 9 | Average Loss: 0.23583 | Average Accuracy: 0.923 | Average Precision: 0.876 | Average Recall: 0.897 | Average F1 Score: 0.886
# Epoch 10 | Average Loss: 0.22764 | Average Accuracy: 0.925 | Average Precision: 0.882 | Average Recall: 0.895 | Average F1 Score: 0.888
# Epoch 11 | Average Loss: 0.22153 | Average Accuracy: 0.927 | Average Precision: 0.887 | Average Recall: 0.895 | Average F1 Score: 0.891
# Epoch 12 | Average Loss: 0.21577 | Average Accuracy: 0.928 | Average Precision: 0.891 | Average Recall: 0.893 | Average F1 Score: 0.892
# Epoch 13 | Average Loss: 0.21310 | Average Accuracy: 0.929 | Average Precision: 0.894 | Average Recall: 0.892 | Average F1 Score: 0.893
# Epoch 14 | Average Loss: 0.20956 | Average Accuracy: 0.930 | Average Precision: 0.897 | Average Recall: 0.893 | Average F1 Score: 0.895
# Epoch 15 | Average Loss: 0.20654 | Average Accuracy: 0.931 | Average Precision: 0.900 | Average Recall: 0.891 | Average F1 Score: 0.895
# Epoch 16 | Average Loss: 0.20498 | Average Accuracy: 0.931 | Average Precision: 0.902 | Average Recall: 0.888 | Average F1 Score: 0.894
# Epoch 17 | Average Loss: 0.20356 | Average Accuracy: 0.932 | Average Precision: 0.905 | Average Recall: 0.889 | Average F1 Score: 0.896
# Epoch 18 | Average Loss: 0.20018 | Average Accuracy: 0.933 | Average Precision: 0.907 | Average Recall: 0.888 | Average F1 Score: 0.897
# Epoch 19 | Average Loss: 0.19745 | Average Accuracy: 0.933 | Average Precision: 0.908 | Average Recall: 0.889 | Average F1 Score: 0.898
# Epoch 20 | Average Loss: 0.19748 | Average Accuracy: 0.933 | Average Precision: 0.910 | Average Recall: 0.886 | Average F1 Score: 0.898
# Epoch 21 | Average Loss: 0.19619 | Average Accuracy: 0.933 | Average Precision: 0.911 | Average Recall: 0.886 | Average F1 Score: 0.898
# Epoch 22 | Average Loss: 0.19448 | Average Accuracy: 0.934 | Average Precision: 0.913 | Average Recall: 0.886 | Average F1 Score: 0.899
# Epoch 23 | Average Loss: 0.19492 | Average Accuracy: 0.933 | Average Precision: 0.913 | Average Recall: 0.883 | Average F1 Score: 0.897
# Epoch 24 | Average Loss: 0.19210 | Average Accuracy: 0.934 | Average Precision: 0.914 | Average Recall: 0.883 | Average F1 Score: 0.897
# Epoch 25 | Average Loss: 0.19167 | Average Accuracy: 0.934 | Average Precision: 0.915 | Average Recall: 0.883 | Average F1 Score: 0.899
# Epoch 26 | Average Loss: 0.19318 | Average Accuracy: 0.933 | Average Precision: 0.915 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 27 | Average Loss: 0.19113 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.880 | Average F1 Score: 0.898
# Epoch 28 | Average Loss: 0.19045 | Average Accuracy: 0.934 | Average Precision: 0.916 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 29 | Average Loss: 0.19106 | Average Accuracy: 0.934 | Average Precision: 0.917 | Average Recall: 0.881 | Average F1 Score: 0.898
# Epoch 30 | Average Loss: 0.19067 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.880 | Average F1 Score: 0.898
# Epoch 31 | Average Loss: 0.18850 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 32 | Average Loss: 0.19001 | Average Accuracy: 0.934 | Average Precision: 0.918 | Average Recall: 0.880 | Average F1 Score: 0.898
# Epoch 33 | Average Loss: 0.18766 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 34 | Average Loss: 0.18839 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 35 | Average Loss: 0.18641 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 36 | Average Loss: 0.18689 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 37 | Average Loss: 0.18642 | Average Accuracy: 0.935 | Average Precision: 0.920 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 38 | Average Loss: 0.18716 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.878 | Average F1 Score: 0.898
# Epoch 39 | Average Loss: 0.18607 | Average Accuracy: 0.934 | Average Precision: 0.920 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 40 | Average Loss: 0.18563 | Average Accuracy: 0.934 | Average Precision: 0.919 | Average Recall: 0.880 | Average F1 Score: 0.899
# Epoch 41 | Average Loss: 0.18635 | Average Accuracy: 0.935 | Average Precision: 0.921 | Average Recall: 0.880 | Average F1 Score: 0.900
# Epoch 42 | Average Loss: 0.18392 | Average Accuracy: 0.935 | Average Precision: 0.920 | Average Recall: 0.882 | Average F1 Score: 0.900
# Epoch 43 | Average Loss: 0.18408 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.881 | Average F1 Score: 0.900
# Epoch 44 | Average Loss: 0.18408 | Average Accuracy: 0.935 | Average Precision: 0.920 | Average Recall: 0.882 | Average F1 Score: 0.901
# Epoch 45 | Average Loss: 0.18457 | Average Accuracy: 0.935 | Average Precision: 0.920 | Average Recall: 0.882 | Average F1 Score: 0.901
# Epoch 46 | Average Loss: 0.18314 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 47 | Average Loss: 0.18282 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.883 | Average F1 Score: 0.901
# Epoch 48 | Average Loss: 0.18365 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 49 | Average Loss: 0.18314 | Average Accuracy: 0.935 | Average Precision: 0.920 | Average Recall: 0.883 | Average F1 Score: 0.901
# Epoch 50 | Average Loss: 0.18332 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 51 | Average Loss: 0.18400 | Average Accuracy: 0.935 | Average Precision: 0.919 | Average Recall: 0.883 | Average F1 Score: 0.900
# Epoch 52 | Average Loss: 0.18193 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 53 | Average Loss: 0.18299 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 54 | Average Loss: 0.18216 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.883 | Average F1 Score: 0.901
# Epoch 55 | Average Loss: 0.18290 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 56 | Average Loss: 0.18120 | Average Accuracy: 0.937 | Average Precision: 0.920 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 57 | Average Loss: 0.18201 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.885 | Average F1 Score: 0.902
# Epoch 58 | Average Loss: 0.18106 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.885 | Average F1 Score: 0.902
# Epoch 59 | Average Loss: 0.18175 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.885 | Average F1 Score: 0.902
# Epoch 60 | Average Loss: 0.18192 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.884 | Average F1 Score: 0.901
# Epoch 61 | Average Loss: 0.18173 | Average Accuracy: 0.936 | Average Precision: 0.918 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 62 | Average Loss: 0.18075 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.887 | Average F1 Score: 0.903
# Epoch 63 | Average Loss: 0.18085 | Average Accuracy: 0.937 | Average Precision: 0.920 | Average Recall: 0.887 | Average F1 Score: 0.903
# Epoch 64 | Average Loss: 0.18145 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 65 | Average Loss: 0.18312 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.885 | Average F1 Score: 0.901
# Epoch 66 | Average Loss: 0.18141 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 67 | Average Loss: 0.18110 | Average Accuracy: 0.936 | Average Precision: 0.919 | Average Recall: 0.886 | Average F1 Score: 0.902
# Epoch 68 | Average Loss: 0.18128 | Average Accuracy: 0.936 | Average Precision: 0.920 | Average Recall: 0.885 | Average F1 Score: 0.902
# Epoch 69 | Average Loss: 0.17990 | Average Accuracy: 0.937 | Average Precision: 0.920 | Average Recall: 0.887 | Average F1 Score: 0.903
